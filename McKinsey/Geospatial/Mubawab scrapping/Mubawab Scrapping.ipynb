# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the page to scrape
url = "https://www.mubawab.ma/en/ct/casablanca/real-estate-for-sale:p:"

# Open a CSV file to write the data to
with open('scrapper/data.csv', 'w', newline='', encoding='utf-8') as csvfile:
    # Define the field names for the CSV file
    fieldnames = ['Title', 'Date', 'Size', 'Location', 'Description', 'Price']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    # Write the header row to the CSV file
    writer.writeheader()

    # Loop over the first five pages of search results
    for page in range(1, 40):
        # Send a request to the URL and get the HTML content
        response = requests.get(url + str(page))
        html_content = response.content

        # Parse the HTML content with Beautiful Soup
        soup = BeautifulSoup(html_content, 'html.parser')
        price_elem = soup.find_all('span', class_=lambda x: x and 'priceTag' in x)
        p=0
        
        for listing in soup.find_all(class_=lambda x: x and 'contentBox' in x):
            # Initialize the row dictionary
            row = {}
            row['Price']= price_elem[p]
            # Extract the title, date, size, price, location, and description from the listing
            title_elem = listing.find('h2', class_='listingTit')
            row['Title'] = title_elem.text.strip() if title_elem is not None else None

            date_elem = listing.find('span', class_='listingDetails iconPadR')
            row['Date'] = date_elem.text.strip() if date_elem is not None else None

            size_elem = listing.find(['h4', 'p'], {'class': 'listingH4 floatR'})
            row['Size'] = size_elem.text.strip() if size_elem is not None else None



            location_elem = listing.find('h3', class_='listingH3')
            row['Location'] = location_elem.text.strip() if location_elem is not None else None

            description_elem = listing.find('p', class_='listingP descLi')
            row['Description'] = description_elem.text.strip() if description_elem is not None else None

            # Write the row to the CSV file
            writer.writerow(row)
            p=p+1

# %%
import pandas as pd
df=pd.read_csv('scrapper/data.csv')
df.head()
# Out:
#                                           Title             Date  \
# 0  Apartment to purchase in Oasis. Surface a...  Published today
# 1   Beautiful apartment for sale in Oasis. 3...  Published today
# 2  Apartment to purchase in Maârif Extension...  Published today
# 3  Apartment to purchase in Ahl Loghlam (Hay...  Published today
# 4  Apartment to purchase in Ahl Loghlam (Hay...  Published today
#
#                  Size                                           Location  \
# 0  3 bedrooms, 128 m²                  Oasis in\n\t \t\t\t\t\tCasablanca
# 1   2 bedrooms, 98 m²                  Oasis in\n\t \t\t\t\t\tCasablanca
# 2   2 bedrooms, 79 m²       Maârif Extension in\n\t \t\t\t\t\tCasablanca
# 3   3 bedrooms, 82 m²  Ahl Loghlam (Hay Assalam) in\n\t \t\t\t\t\tCas...
# 4   3 bedrooms, 67 m²  Ahl Loghlam (Hay Assalam) in\n\t \t\t\t\t\tCas...
#
#                                          Description  \
# 0  don't miss out on this apartment for sale. pri...
# 1  amazing deal on this apartment for sale. price...
# 2  ideal for investors or young professionals loo...
# 3  it is in the heart of the new city of tit mell...
# 4  it is in the heart of the new city of tit mell...
#
#                                                Price
# 0  <span class="priceTag hardShadow float-right f...
# 1  <span class="priceTag hardShadow float-right f...
# 2  <span class="priceTag hardShadow float-right f...
# 3  <span class="priceTag hardShadow float-right f...
# 4  <span class="priceTag hardShadow float-right f...

# %%
import re
df['Price'] = df['Price'].apply(lambda x: re.sub('[^0-9,]', '', x))  # remove non-numeric characters
df['Price'] = df['Price'].apply(lambda x: re.sub(',', '.', x))  # replace commas with dots

# %%
df.head()
# Out:
#                                           Title             Date  \
# 0  Apartment to purchase in Oasis. Surface a...  Published today
# 1   Beautiful apartment for sale in Oasis. 3...  Published today
# 2  Apartment to purchase in Maârif Extension...  Published today
# 3  Apartment to purchase in Ahl Loghlam (Hay...  Published today
# 4  Apartment to purchase in Ahl Loghlam (Hay...  Published today
#
#                  Size                                           Location  \
# 0  3 bedrooms, 128 m²                  Oasis in\n\t \t\t\t\t\tCasablanca
# 1   2 bedrooms, 98 m²                  Oasis in\n\t \t\t\t\t\tCasablanca
# 2   2 bedrooms, 79 m²       Maârif Extension in\n\t \t\t\t\t\tCasablanca
# 3   3 bedrooms, 82 m²  Ahl Loghlam (Hay Assalam) in\n\t \t\t\t\t\tCas...
# 4   3 bedrooms, 67 m²  Ahl Loghlam (Hay Assalam) in\n\t \t\t\t\t\tCas...
#
#                                          Description      Price
# 0  don't miss out on this apartment for sale. pri...  2.640.000
# 1  amazing deal on this apartment for sale. price...  1.900.000
# 2  ideal for investors or young professionals loo...  1.561.000
# 3  it is in the heart of the new city of tit mell...    340.000
# 4  it is in the heart of the new city of tit mell...    250.000

# %%
df[['NumBedrooms', 'Size']] = df['Size'].str.split(',', expand=True)
df.head()
# Out:
#                                           Title             Date     Size  \
# 0  Apartment to purchase in Oasis. Surface a...  Published today   128 m²
# 1   Beautiful apartment for sale in Oasis. 3...  Published today    98 m²
# 2  Apartment to purchase in Maârif Extension...  Published today    79 m²
# 3  Apartment to purchase in Ahl Loghlam (Hay...  Published today    82 m²
# 4  Apartment to purchase in Ahl Loghlam (Hay...  Published today    67 m²
#
#                                             Location  \
# 0                  Oasis in\n\t \t\t\t\t\tCasablanca
# 1                  Oasis in\n\t \t\t\t\t\tCasablanca
# 2       Maârif Extension in\n\t \t\t\t\t\tCasablanca
# 3  Ahl Loghlam (Hay Assalam) in\n\t \t\t\t\t\tCas...
# 4  Ahl Loghlam (Hay Assalam) in\n\t \t\t\t\t\tCas...
#
#                                          Description      Price NumBedrooms
# 0  don't miss out on this apartment for sale. pri...  2.640.000  3 bedrooms
# 1  amazing deal on this apartment for sale. price...  1.900.000  2 bedrooms
# 2  ideal for investors or young professionals loo...  1.561.000  2 bedrooms
# 3  it is in the heart of the new city of tit mell...    340.000  3 bedrooms
# 4  it is in the heart of the new city of tit mell...    250.000  3 bedrooms

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1326 entries, 0 to 1325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        1326 non-null   object
#  1   Date         1287 non-null   object
#  2   Size         1284 non-null   object
#  3   Location     1326 non-null   object
#  4   Description  1326 non-null   object
#  5   Price        1326 non-null   object
#  6   NumBedrooms  1287 non-null   object
# dtypes: object(7)
# memory usage: 72.6+ KB

# %%
df['Location'] = df['Location'].apply(lambda x: re.sub('in\n   \t\t\t\t\tCasablanca', '', x))  # replace commas with dots
df['Location'] = df['Location'].apply(lambda x: re.sub('in\n   \t\t\t\t\t\tCasablanca', '', x))  # replace commas with dots
df['Location'] = df['Location'].apply(lambda x: re.sub('Casablanca', '', x))  # replace commas with dots

df['Location'] = df['Location'].apply(lambda x: re.sub('in\n\t \t\t\t\t\t', '', x))  # replace commas with dots
df['Location'] = df['Location'].apply(lambda x: re.sub('in\n \t\t\t\t\t', '', x))  # replace commas with dots

df.head()
# Out:
#                                           Title             Date     Size  \
# 0  Apartment to purchase in Oasis. Surface a...  Published today   128 m²
# 1   Beautiful apartment for sale in Oasis. 3...  Published today    98 m²
# 2  Apartment to purchase in Maârif Extension...  Published today    79 m²
# 3  Apartment to purchase in Ahl Loghlam (Hay...  Published today    82 m²
# 4  Apartment to purchase in Ahl Loghlam (Hay...  Published today    67 m²
#
#                      Location  \
# 0                      Oasis
# 1                      Oasis
# 2           Maârif Extension
# 3  Ahl Loghlam (Hay Assalam)
# 4  Ahl Loghlam (Hay Assalam)
#
#                                          Description      Price NumBedrooms
# 0  don't miss out on this apartment for sale. pri...  2.640.000           3
# 1  amazing deal on this apartment for sale. price...  1.900.000           2
# 2  ideal for investors or young professionals loo...  1.561.000           2
# 3  it is in the heart of the new city of tit mell...    340.000           3
# 4  it is in the heart of the new city of tit mell...    250.000           3

# %%
df['NumBedrooms'] = df['NumBedrooms'].str.extract('(\d+)', expand=False)  # extract the digits from the string

df.head()
# Out:
#                                           Title             Date     Size  \
# 0  Apartment to purchase in Oasis. Surface a...  Published today   128 m²
# 1   Beautiful apartment for sale in Oasis. 3...  Published today    98 m²
# 2  Apartment to purchase in Maârif Extension...  Published today    79 m²
# 3  Apartment to purchase in Ahl Loghlam (Hay...  Published today    82 m²
# 4  Apartment to purchase in Ahl Loghlam (Hay...  Published today    67 m²
#
#                                Location  \
# 0                      Oasis Casablanca
# 1                      Oasis Casablanca
# 2           Maârif Extension Casablanca
# 3  Ahl Loghlam (Hay Assalam) Casablanca
# 4  Ahl Loghlam (Hay Assalam) Casablanca
#
#                                          Description      Price NumBedrooms
# 0  don't miss out on this apartment for sale. pri...  2.640.000           3
# 1  amazing deal on this apartment for sale. price...  1.900.000           2
# 2  ideal for investors or young professionals loo...  1.561.000           2
# 3  it is in the heart of the new city of tit mell...    340.000           3
# 4  it is in the heart of the new city of tit mell...    250.000           3

# %%
df.describe()
# Out:
#                                                Title             Date    Size  \
# count                                           1326             1287    1284
# unique                                           839                8     376
# top     Apartment to purchase in Al Azhar. 1 love...  Published today   50 m²
# freq                                              20              454      23
#
#            Location                                        Description  \
# count          1326                                               1326
# unique           93                                               1156
# top     Californie   the boulevard de biarritz becomes the new luxu...
# freq            107                                                 13
#
#           Price NumBedrooms
# count      1326        1287
# unique      573          12
# top     250.000           3
# freq         50         436
